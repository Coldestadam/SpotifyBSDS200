# %%
from pathlib import Path
import pandas as pd
from dataloader import load_data

# %%
all_dfs = load_data(Path.cwd())
# Out:
# ...
# Reading data from disk...this may take a minute: 100%|██████████| 3/3 [00:33<00:00, 11.29s/it]

# %%
all_dfs.keys()
# Out:
# dict_keys(['albums', 'artist_socials', 'twitter'])

# %%
print(all_dfs['albums'].columns)
print(all_dfs['albums'].info())
all_dfs['albums'].head()
# Out:
# Index(['name', 'year', 'track_count', 'month', 'day', 'album_id', 'artist_id',
#        'release_type', 'release_date'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3301635 entries, 0 to 3301634
# Data columns (total 9 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   name          string
#  1   year          Int64
#  2   track_count   Int64
#  3   month         Int64
#  4   day           Int64
#  5   album_id      string
#  6   artist_id     string
#  7   release_type  string
#  8   release_date  string
# dtypes: Int64(4), string(5)
# memory usage: 239.3 MB
# None
#                         name  year  track_count  month  day  \
# 0                  The Ocean  2019            1      1   16
# 1                  Hula Hoop  2019            1      1   16
# 2                  Boyfriend  2019            3     10   30
# 3                  Firestone  2019            1      1   16
# ...

# %%
print(all_dfs['twitter'].columns)
print(all_dfs['twitter'].info())
all_dfs['twitter'].head()
# Out:
# Index(['id', 'name', 'username', 'bio', 'location', 'url', 'join_date',
#        'join_time', 'tweets', 'following', 'followers', 'likes', 'media',
#        'private', 'verified', 'profile_image_url', 'background_image'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77786 entries, 0 to 77785
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 77785 non-null  object
#  1   name               77601 non-null  object
#  2   username           77623 non-null  object
#  3   bio                71726 non-null  object
#  4   location           56494 non-null  object
#  5   url                69038 non-null  object
#  6   join_date          77388 non-null  object
#  7   join_time          77388 non-null  object
#  8   tweets             77388 non-null  float64
#  9   following          77388 non-null  float64
# ...

# %%
twitter = all_dfs['twitter'].convert_dtypes()
twitter
# Out:
#                         id                    name        username  \
# 0                 35414263                AUNTIE G      Gifted_Gab
# 1                 35414263                AUNTIE G      Gifted_Gab
# 2               3293453286     The Sisterhood Band   thesisterhood
# 3                237390278  DJ VIRUS DI UNRULY ONE     Unrulyvirus
# 4                237390278  DJ VIRUS DI UNRULY ONE     Unrulyvirus
# ...                    ...                     ...             ...
# 77781  1012261389988081664                    Elin       elin_WRLD
# 77782             29855450             B4G Tha Kid       b4gthakid
# 77783             29413922               Big Dreez          drezus
# 77784             37585364              MEGAHURTZ™    megahurtzedm
# 77785            487886074              Jan Martin  JanMartinMusic
#
#                                                      bio  \
# 0      Want to impress me? Jump in the air & stay the...
# ...

# %%
all_dfs['twitter'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77786 entries, 0 to 77785
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 77785 non-null  object
#  1   name               77601 non-null  object
#  2   username           77623 non-null  object
#  3   bio                71726 non-null  object
#  4   location           56494 non-null  object
#  5   url                69038 non-null  object
#  6   join_date          77388 non-null  object
#  7   join_time          77388 non-null  object
#  8   tweets             77388 non-null  float64
#  9   following          77388 non-null  float64
#  10  followers          77388 non-null  float64
#  11  likes              77388 non-null  float64
#  12  media              77388 non-null  object
#  13  private            77345 non-null  object
#  14  verified           77132 non-null  float64
#  15  profile_image_url  77132 non-null  object
# ...

# %%
print(all_dfs['artist_socials'].info())
all_dfs['artist_socials'].tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 333033 entries, 0 to 333032
# Data columns (total 4 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   artist_id       333033 non-null  object
#  1   follower_count  333033 non-null  int64
#  2   instagram       232845 non-null  object
#  3   twitter         164696 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 10.2+ MB
# None
#                      artist_id  follower_count  \
# 333028  1vpKzMP5zYX0y0x0PwFPJF              92
# 333029  5IbMXzqnGCm3WKt3XweUCn             439
# 333030  5IbMXzqnGCm3WKt3XweUCn             439
# 333031  5IbMXzqnGCm3WKt3XweUCn             439
# 333032  5IbMXzqnGCm3WKt3XweUCn             439
#
#                                  instagram                        twitter
# 333028  https://instagram.com/nateconner23  https://twitter.com/nconner23
# 333029       https://instagram.com/ynbilly  https://twitter.com/ynbilly93
# ...

# %%
all_dfs['twitter'].loc[1860:1865, :]
# Out:
#                             id           name       username  \
# 1860                3026114939  Nikko Tank 🇬🇷      nikkotank
# 1861       1218002693865857024  Lost Symphony  lostsymphony1
# 1862                 270003218  Necronautical  Necronautical
# 1863       CARCARRION: Guitar,           <NA>           <NA>
# 1864   ANCHORITE: Bass Guitar,           <NA>           <NA>
# 1865           SLUGH: Drums.             <NA>           <NA>
#
#                                                     bio     location  \
# 1860              NEW MUSIC BELOW :📧mr.boumboulis@gmail  Wheaton, MD
# 1861  Debut album ‘Chapter I’ available everywhere N...         <NA>
# 1862                             NAUT: Vocals & Guitar,         <NA>
# 1863                                               <NA>         <NA>
# 1864                                               <NA>         <NA>
# 1865                                               <NA>         <NA>
#
# ...

# %%
all_dfs['twitter'] = all_dfs['twitter'].where(all_dfs['twitter'].notnull(), None)
all_dfs['twitter'].loc[1860:1865, :]
# Out:
#                             id           name       username  \
# 1860                3026114939  Nikko Tank 🇬🇷      nikkotank
# 1861       1218002693865857024  Lost Symphony  lostsymphony1
# 1862                 270003218  Necronautical  Necronautical
# 1863       CARCARRION: Guitar,           None           None
# 1864   ANCHORITE: Bass Guitar,           None           None
# 1865           SLUGH: Drums.             None           None
#
#                                                     bio     location  \
# 1860              NEW MUSIC BELOW :📧mr.boumboulis@gmail  Wheaton, MD
# 1861  Debut album ‘Chapter I’ available everywhere N...         None
# 1862                             NAUT: Vocals & Guitar,         None
# 1863                                               None         None
# 1864                                               None         None
# 1865                                               None         None
#
# ...

# %%
all_dfs['twitter'] = all_dfs['twitter'].convert_dtypes() 
all_dfs['twitter'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77786 entries, 0 to 77785
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 77785 non-null  string
#  1   name               77601 non-null  string
#  2   username           77623 non-null  string
#  3   bio                71726 non-null  string
#  4   location           56494 non-null  string
#  5   url                69038 non-null  string
#  6   join_date          77388 non-null  string
#  7   join_time          77388 non-null  string
#  8   tweets             77388 non-null  Int64
#  9   following          77388 non-null  Int64
#  10  followers          77388 non-null  Int64
#  11  likes              77388 non-null  Int64
#  12  media              77388 non-null  string
#  13  private            77345 non-null  string
#  14  verified           77132 non-null  Int64
#  15  profile_image_url  77132 non-null  string
# ...

# %%
import sqlalchemy
from sqlalchemy.types import BOOLEAN, INT, BIGINT, DateTime, Text
import psycopg2

# username = 'aevillarreal'
# password = 'Second12'

username = 'krmiddlebrook'
password = 'Transit13'

schema_name = 'song_pop'


db_url = f'postgresql://{username}:{password}@bsds200.c3ogcwmqzllz.us-east-1.rds.amazonaws.com/bsdsclass'
db = sqlalchemy.create_engine(db_url)

# %%
with db.connect() as conn:
    query = f'''
            DROP Table {schema_name}.twitter_test;
        '''
    conn.execute(query)

# %%
query = '''
    SELECT * FROM song_pop.twitter_test LIMIT 10;
'''
table = pd.read_sql(query, con=db)

# %%
twitter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77786 entries, 0 to 77785
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 77785 non-null  string
#  1   name               77601 non-null  string
#  2   username           77623 non-null  string
#  3   bio                71726 non-null  string
#  4   location           56494 non-null  string
#  5   url                69038 non-null  string
#  6   join_date          77388 non-null  string
#  7   join_time          77388 non-null  string
#  8   tweets             77388 non-null  Int64
#  9   following          77388 non-null  Int64
#  10  followers          77388 non-null  Int64
#  11  likes              77388 non-null  Int64
#  12  media              77388 non-null  string
#  13  private            77345 non-null  string
#  14  verified           77132 non-null  Int64
#  15  profile_image_url  77132 non-null  string
# ...

# %%
cols = ['id', 'name', 'username', 'bio', 'location', 'url', 'join_date', 'join_time', 'media', 'private', 'profile_image_url', 'background_image']
twitter.loc[:, cols] = twitter.loc[:, cols].fillna('')

# %%
cols = ['tweets', 'following', 'followers', 'likes', 'verified']
twitter.loc[:, cols] = twitter.loc[:, cols].fillna(0)

# %%
twitter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77786 entries, 0 to 77785
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 77786 non-null  string
#  1   name               77786 non-null  string
#  2   username           77786 non-null  string
#  3   bio                77786 non-null  string
#  4   location           77786 non-null  string
#  5   url                77786 non-null  string
#  6   join_date          77786 non-null  string
#  7   join_time          77786 non-null  string
#  8   tweets             77786 non-null  Int64
#  9   following          77786 non-null  Int64
#  10  followers          77786 non-null  Int64
#  11  likes              77786 non-null  Int64
#  12  media              77786 non-null  string
#  13  private            77786 non-null  string
#  14  verified           77786 non-null  Int64
#  15  profile_image_url  77786 non-null  string
# ...

# %%
all_dfs['albums'].loc[:10, :].to_sql(
    name='albums',
    con=db,
    schema=schema_name,
    index=False,
    if_exists="replace",
    method="multi",
)

# %%
print(all_dfs['albums'].shape[0])
list(range(0, all_dfs['albums'].shape[0], 1000))[0]
# Out:
# 3301635
# 0

# %%
all_dfs['albums'].loc[3301000:None, :]
# Out:
#                                                name  year  track_count  month  \
# 3301000                              Lakes of Flame  2018            2     12
# 3301001                       The Devil (ANX Remix)  2018            2      8
# 3301002                           Antisleep Vol. 01  2008           18      1
# 3301003  Not Over Til We Say So (Rabbit Junk Remix)  2018            2      5
# 3301004               ULTRAnumb (Celldweller Remix)  2018            1     11
# ...                                             ...   ...          ...    ...
# 3301630                                Stay with Me  2018            2      9
# 3301631                                 Toxic Candy  2013           14     10
# 3301632                                   This Time  2013            1      5
# 3301633                                   Don Julio  2019            1      1
# 3301634                                      Liquid  2020            1      1
#
# ...

# %%
all_dfs['twitter'].to_parquet('data/twitter.parquet', index=False)

# %%
albums = pd.read_parquet('data/albums.parquet')
albums.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3448926 entries, 0 to 3448925
# Data columns (total 9 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   name          object
#  1   year          int64
#  2   track_count   int64
#  3   month         float64
#  4   day           float64
#  5   album_id      object
#  6   artist_id     object
#  7   release_type  object
#  8   release_date  datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(2), object(4)
# memory usage: 236.8+ MB

# %%
albums = albums.convert_dtypes()
albums.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3448926 entries, 0 to 3448925
# Data columns (total 9 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   name          string
#  1   year          Int64
#  2   track_count   Int64
#  3   month         Int64
#  4   day           Int64
#  5   album_id      string
#  6   artist_id     string
#  7   release_type  string
#  8   release_date  datetime64[ns]
# dtypes: Int64(4), datetime64[ns](1), string(4)
# memory usage: 250.0 MB

# %%
albums = pd.read_csv('data/albums.tdf', sep='\t', engine='python')
albums = albums.convert_dtypes()
albums.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3301635 entries, 0 to 3301634
# Data columns (total 9 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   name          string
#  1   year          Int64
#  2   track_count   Int64
#  3   month         Int64
#  4   day           Int64
#  5   album_id      string
#  6   artist_id     string
#  7   release_type  string
#  8   release_date  string
# dtypes: Int64(4), string(5)
# memory usage: 239.3 MB

# %%
3301965

# %%
albums.loc[0:50, :].shape
# Out:
# (51, 9)
